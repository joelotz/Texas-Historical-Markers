# %% [raw]
# ==============================================================
# Texas Historical Marker Filter & Export Script
# ==============================================================
#
# Purpose:
#     Generates county-separated CSV files containing ONLY historical
#     markers that have no HMDB reference assigned (ref:hmdb missing/blank),
#     excluding markers that are marked as Missing OR Private.
#
# Inputs:
#     • data.csv (expected in same directory as script)
#
# Filters Applied:
#     1. ref:hmdb is NaN or blank → *unmapped markers only*
#     2. Exclude rows where:
#          - isMissing == True
#          - isPrivate == True
#
# Outputs:
#     Creates a directory:
#         ./UnmappedMarkersPerCounty/
#     Inside it, generates one CSV per county:
#         <county_name>.csv
#
# Notes:
#     • If the output folder doesn't exist, it will be created automatically.
#     • If a file already exists for a county, it will be overwritten.
#     • Filenames are sanitized to avoid spaces and slashes.
# ==============================================================

# %%
import os
import pandas as pd

# === Create output directory if missing ===
OUTPUT_DIR = "UnmappedMarkersPerCounty"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# === Load data ===
df = pd.read_csv("data.csv", low_memory=False)

# === Base filter: ref:hmdb is empty/blank/NaN ===
base_filtered = df[df["ref:hmdb"].isna() | (df["ref:hmdb"].astype(str).str.strip() == "")]

# === Remove if isMissing == True OR isPrivate == True ===
# Handles cases where values may not be boolean or may be NaN
filtered = base_filtered[
    ~((base_filtered.get("isMissing") == True) | (base_filtered.get("isPrivate") == True))
]

# === Group by county and export ===
for county, group in filtered.groupby("addr:county"):
    safe_name = str(county).replace(" ", "_").replace("/", "-")
    outfile = os.path.join(OUTPUT_DIR, f"{safe_name}.csv")
    
    group.to_csv(outfile, index=False)  # overwrite is default behavior
    print(f"Saved: {outfile} ({len(group)} rows)")
# Out:
# Saved: UnmappedMarkersPerCounty/Anderson.csv (62 rows)
# Saved: UnmappedMarkersPerCounty/Andrews.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Angelina.csv (33 rows)
# Saved: UnmappedMarkersPerCounty/Aransas.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Archer.csv (16 rows)
# Saved: UnmappedMarkersPerCounty/Armstrong.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Atascosa.csv (9 rows)
# Saved: UnmappedMarkersPerCounty/Austin.csv (41 rows)
# Saved: UnmappedMarkersPerCounty/Bailey.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Bandera.csv (8 rows)
# Saved: UnmappedMarkersPerCounty/Bastrop.csv (48 rows)
# Saved: UnmappedMarkersPerCounty/Baylor.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Bee.csv (11 rows)
# Saved: UnmappedMarkersPerCounty/Bell.csv (118 rows)
# Saved: UnmappedMarkersPerCounty/Bexar.csv (92 rows)
# Saved: UnmappedMarkersPerCounty/Blanco.csv (4 rows)
# Saved: UnmappedMarkersPerCounty/Bosque.csv (32 rows)
# Saved: UnmappedMarkersPerCounty/Bowie.csv (40 rows)
# Saved: UnmappedMarkersPerCounty/Brazoria.csv (20 rows)
# Saved: UnmappedMarkersPerCounty/Brazos.csv (36 rows)
# Saved: UnmappedMarkersPerCounty/Brewster.csv (7 rows)
# Saved: UnmappedMarkersPerCounty/Brooks.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Brown.csv (33 rows)
# Saved: UnmappedMarkersPerCounty/Burleson.csv (24 rows)
# Saved: UnmappedMarkersPerCounty/Burnet.csv (12 rows)
# Saved: UnmappedMarkersPerCounty/Caldwell.csv (20 rows)
# Saved: UnmappedMarkersPerCounty/Calhoun.csv (11 rows)
# Saved: UnmappedMarkersPerCounty/Callahan.csv (7 rows)
# Saved: UnmappedMarkersPerCounty/Cameron.csv (52 rows)
# Saved: UnmappedMarkersPerCounty/Camp.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Carson.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Cass.csv (28 rows)
# Saved: UnmappedMarkersPerCounty/Chambers.csv (14 rows)
# Saved: UnmappedMarkersPerCounty/Cherokee.csv (97 rows)
# Saved: UnmappedMarkersPerCounty/Childress.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Clay.csv (9 rows)
# Saved: UnmappedMarkersPerCounty/Cochran.csv (4 rows)
# Saved: UnmappedMarkersPerCounty/Coke.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Coleman.csv (7 rows)
# Saved: UnmappedMarkersPerCounty/Collin.csv (36 rows)
# Saved: UnmappedMarkersPerCounty/Colorado.csv (16 rows)
# Saved: UnmappedMarkersPerCounty/Comal.csv (44 rows)
# Saved: UnmappedMarkersPerCounty/Comanche.csv (28 rows)
# Saved: UnmappedMarkersPerCounty/Concho.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Cooke.csv (17 rows)
# Saved: UnmappedMarkersPerCounty/Coryell.csv (37 rows)
# Saved: UnmappedMarkersPerCounty/Cottle.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Crane.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Crockett.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Crosby.csv (4 rows)
# Saved: UnmappedMarkersPerCounty/Culberson.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Dallas.csv (59 rows)
# Saved: UnmappedMarkersPerCounty/DeWitt.csv (48 rows)
# Saved: UnmappedMarkersPerCounty/Deaf_Smith.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Delta.csv (24 rows)
# Saved: UnmappedMarkersPerCounty/Denton.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Dickens.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Dimmit.csv (5 rows)
# Saved: UnmappedMarkersPerCounty/Donley.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Duval.csv (9 rows)
# Saved: UnmappedMarkersPerCounty/Eastland.csv (19 rows)
# Saved: UnmappedMarkersPerCounty/Ector.csv (14 rows)
# Saved: UnmappedMarkersPerCounty/Edwards.csv (4 rows)
# Saved: UnmappedMarkersPerCounty/El_Paso.csv (67 rows)
# Saved: UnmappedMarkersPerCounty/Ellis.csv (36 rows)
# Saved: UnmappedMarkersPerCounty/Erath.csv (46 rows)
# Saved: UnmappedMarkersPerCounty/Falls.csv (49 rows)
# Saved: UnmappedMarkersPerCounty/Fannin.csv (58 rows)
# Saved: UnmappedMarkersPerCounty/Fayette.csv (52 rows)
# Saved: UnmappedMarkersPerCounty/Fisher.csv (10 rows)
# Saved: UnmappedMarkersPerCounty/Fort_Bend.csv (10 rows)
# Saved: UnmappedMarkersPerCounty/Franklin.csv (10 rows)
# Saved: UnmappedMarkersPerCounty/Freestone.csv (39 rows)
# Saved: UnmappedMarkersPerCounty/Frio.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Gaines.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Galveston.csv (45 rows)
# Saved: UnmappedMarkersPerCounty/Garza.csv (5 rows)
# Saved: UnmappedMarkersPerCounty/Gillespie.csv (27 rows)
# Saved: UnmappedMarkersPerCounty/Goliad.csv (17 rows)
# Saved: UnmappedMarkersPerCounty/Gonzales.csv (52 rows)
# Saved: UnmappedMarkersPerCounty/Gray.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Grayson.csv (54 rows)
# Saved: UnmappedMarkersPerCounty/Gregg.csv (59 rows)
# Saved: UnmappedMarkersPerCounty/Grimes.csv (35 rows)
# Saved: UnmappedMarkersPerCounty/Guadalupe.csv (21 rows)
# Saved: UnmappedMarkersPerCounty/Hale.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Hall.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Hamilton.csv (19 rows)
# Saved: UnmappedMarkersPerCounty/Hansford.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Hardeman.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Hardin.csv (21 rows)
# Saved: UnmappedMarkersPerCounty/Harris.csv (87 rows)
# Saved: UnmappedMarkersPerCounty/Harrison.csv (61 rows)
# Saved: UnmappedMarkersPerCounty/Hartley.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Haskell.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Hays.csv (48 rows)
# Saved: UnmappedMarkersPerCounty/Henderson.csv (70 rows)
# Saved: UnmappedMarkersPerCounty/Hidalgo.csv (60 rows)
# Saved: UnmappedMarkersPerCounty/Hill.csv (47 rows)
# Saved: UnmappedMarkersPerCounty/Hockley.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Hood.csv (30 rows)
# Saved: UnmappedMarkersPerCounty/Hopkins.csv (21 rows)
# Saved: UnmappedMarkersPerCounty/Houston.csv (129 rows)
# Saved: UnmappedMarkersPerCounty/Howard.csv (5 rows)
# Saved: UnmappedMarkersPerCounty/Hudspeth.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Hunt.csv (39 rows)
# Saved: UnmappedMarkersPerCounty/Irion.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Jack.csv (14 rows)
# Saved: UnmappedMarkersPerCounty/Jackson.csv (23 rows)
# Saved: UnmappedMarkersPerCounty/Jasper.csv (45 rows)
# Saved: UnmappedMarkersPerCounty/Jeff_Davis.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Jefferson.csv (41 rows)
# Saved: UnmappedMarkersPerCounty/Jim_Hogg.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Jim_Wells.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Johnson.csv (34 rows)
# Saved: UnmappedMarkersPerCounty/Jones.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Karnes.csv (5 rows)
# Saved: UnmappedMarkersPerCounty/Kaufman.csv (11 rows)
# Saved: UnmappedMarkersPerCounty/Kendall.csv (19 rows)
# Saved: UnmappedMarkersPerCounty/Kenedy.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Kerr.csv (12 rows)
# Saved: UnmappedMarkersPerCounty/Kimble.csv (10 rows)
# Saved: UnmappedMarkersPerCounty/King.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Kinney.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Kleberg.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Knox.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/La_Salle.csv (5 rows)
# Saved: UnmappedMarkersPerCounty/Lamar.csv (39 rows)
# Saved: UnmappedMarkersPerCounty/Lamb.csv (5 rows)
# Saved: UnmappedMarkersPerCounty/Lampasas.csv (34 rows)
# Saved: UnmappedMarkersPerCounty/Lavaca.csv (58 rows)
# Saved: UnmappedMarkersPerCounty/Lee.csv (27 rows)
# Saved: UnmappedMarkersPerCounty/Leon.csv (20 rows)
# Saved: UnmappedMarkersPerCounty/Liberty.csv (18 rows)
# Saved: UnmappedMarkersPerCounty/Limestone.csv (58 rows)
# Saved: UnmappedMarkersPerCounty/Lipscomb.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Live_Oak.csv (12 rows)
# Saved: UnmappedMarkersPerCounty/Llano.csv (10 rows)
# Saved: UnmappedMarkersPerCounty/Lubbock.csv (16 rows)
# Saved: UnmappedMarkersPerCounty/Lynn.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Madison.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Marion.csv (76 rows)
# Saved: UnmappedMarkersPerCounty/Martin.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Mason.csv (5 rows)
# Saved: UnmappedMarkersPerCounty/Matagorda.csv (43 rows)
# Saved: UnmappedMarkersPerCounty/Maverick.csv (8 rows)
# Saved: UnmappedMarkersPerCounty/McCulloch.csv (9 rows)
# Saved: UnmappedMarkersPerCounty/McLennan.csv (88 rows)
# Saved: UnmappedMarkersPerCounty/McMullen.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Medina.csv (11 rows)
# Saved: UnmappedMarkersPerCounty/Menard.csv (5 rows)
# Saved: UnmappedMarkersPerCounty/Midland.csv (11 rows)
# Saved: UnmappedMarkersPerCounty/Milam.csv (49 rows)
# Saved: UnmappedMarkersPerCounty/Mills.csv (7 rows)
# Saved: UnmappedMarkersPerCounty/Mitchell.csv (14 rows)
# Saved: UnmappedMarkersPerCounty/Montague.csv (29 rows)
# Saved: UnmappedMarkersPerCounty/Montgomery.csv (28 rows)
# Saved: UnmappedMarkersPerCounty/Morris.csv (12 rows)
# Saved: UnmappedMarkersPerCounty/Nacogdoches.csv (52 rows)
# Saved: UnmappedMarkersPerCounty/Navarro.csv (57 rows)
# Saved: UnmappedMarkersPerCounty/Newton.csv (43 rows)
# Saved: UnmappedMarkersPerCounty/Nolan.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Nueces.csv (14 rows)
# Saved: UnmappedMarkersPerCounty/Ochiltree.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Oldham.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Orange.csv (34 rows)
# Saved: UnmappedMarkersPerCounty/Palo_Pinto.csv (22 rows)
# Saved: UnmappedMarkersPerCounty/Panola.csv (40 rows)
# Saved: UnmappedMarkersPerCounty/Parker.csv (50 rows)
# Saved: UnmappedMarkersPerCounty/Parmer.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Pecos.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Polk.csv (36 rows)
# Saved: UnmappedMarkersPerCounty/Potter.csv (15 rows)
# Saved: UnmappedMarkersPerCounty/Presidio.csv (5 rows)
# Saved: UnmappedMarkersPerCounty/Rains.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Randall.csv (7 rows)
# Saved: UnmappedMarkersPerCounty/Reagan.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Real.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Red_River.csv (33 rows)
# Saved: UnmappedMarkersPerCounty/Reeves.csv (4 rows)
# Saved: UnmappedMarkersPerCounty/Refugio.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Robertson.csv (38 rows)
# Saved: UnmappedMarkersPerCounty/Rockwall.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Runnels.csv (8 rows)
# Saved: UnmappedMarkersPerCounty/Rusk.csv (94 rows)
# Saved: UnmappedMarkersPerCounty/Sabine.csv (47 rows)
# Saved: UnmappedMarkersPerCounty/San_Augustine.csv (46 rows)
# Saved: UnmappedMarkersPerCounty/San_Jacinto.csv (11 rows)
# Saved: UnmappedMarkersPerCounty/San_Patricio.csv (4 rows)
# Saved: UnmappedMarkersPerCounty/San_Saba.csv (23 rows)
# Saved: UnmappedMarkersPerCounty/Schleicher.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Scurry.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Shackelford.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Shelby.csv (52 rows)
# Saved: UnmappedMarkersPerCounty/Sherman.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Smith.csv (30 rows)
# Saved: UnmappedMarkersPerCounty/Somervell.csv (7 rows)
# Saved: UnmappedMarkersPerCounty/Starr.csv (25 rows)
# Saved: UnmappedMarkersPerCounty/Stephens.csv (14 rows)
# Saved: UnmappedMarkersPerCounty/Sterling.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Stonewall.csv (3 rows)
# Saved: UnmappedMarkersPerCounty/Sutton.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Swisher.csv (4 rows)
# Saved: UnmappedMarkersPerCounty/Tarrant.csv (129 rows)
# Saved: UnmappedMarkersPerCounty/Taylor.csv (7 rows)
# Saved: UnmappedMarkersPerCounty/Terrell.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Throckmorton.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Titus.csv (10 rows)
# Saved: UnmappedMarkersPerCounty/Tom_Green.csv (14 rows)
# Saved: UnmappedMarkersPerCounty/Travis.csv (75 rows)
# Saved: UnmappedMarkersPerCounty/Trinity.csv (29 rows)
# Saved: UnmappedMarkersPerCounty/Tyler.csv (27 rows)
# Saved: UnmappedMarkersPerCounty/Upshur.csv (47 rows)
# Saved: UnmappedMarkersPerCounty/Upton.csv (4 rows)
# Saved: UnmappedMarkersPerCounty/Uvalde.csv (8 rows)
# Saved: UnmappedMarkersPerCounty/Val_Verde.csv (8 rows)
# Saved: UnmappedMarkersPerCounty/Van_Zandt.csv (56 rows)
# Saved: UnmappedMarkersPerCounty/Victoria.csv (25 rows)
# Saved: UnmappedMarkersPerCounty/Walker.csv (43 rows)
# Saved: UnmappedMarkersPerCounty/Waller.csv (8 rows)
# Saved: UnmappedMarkersPerCounty/Ward.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Washington.csv (70 rows)
# Saved: UnmappedMarkersPerCounty/Webb.csv (23 rows)
# Saved: UnmappedMarkersPerCounty/Wharton.csv (28 rows)
# Saved: UnmappedMarkersPerCounty/Wheeler.csv (6 rows)
# Saved: UnmappedMarkersPerCounty/Wichita.csv (73 rows)
# Saved: UnmappedMarkersPerCounty/Wilbarger.csv (2 rows)
# Saved: UnmappedMarkersPerCounty/Willacy.csv (12 rows)
# Saved: UnmappedMarkersPerCounty/Williamson.csv (28 rows)
# Saved: UnmappedMarkersPerCounty/Wilson.csv (13 rows)
# Saved: UnmappedMarkersPerCounty/Winkler.csv (1 rows)
# Saved: UnmappedMarkersPerCounty/Wise.csv (36 rows)
# Saved: UnmappedMarkersPerCounty/Wood.csv (39 rows)
# Saved: UnmappedMarkersPerCounty/Young.csv (12 rows)
# Saved: UnmappedMarkersPerCounty/Zapata.csv (8 rows)
# Saved: UnmappedMarkersPerCounty/Zavala.csv (3 rows)

# %%
# summary = filtered.groupby("addr:county").size().sort_values(ascending=False)
counts = filtered.groupby("addr:county").size()

counts[counts <= 1]
# Out:
# addr:county
# Aransas       1
# Briscoe       1
# Castro        1
# Coke          1
# Cottle        1
# Crockett      1
# Dallam        1
# Donley        1
# Floyd         1
# Foard         1
# Hansford      1
# Hartley       1
# Hemphill      1
# Jeff Davis    1
# King          1
# Lipscomb      1
# Martin        1
# Moore         1
# Ochiltree     1
# Schleicher    1
# Yoakum        1
# dtype: int64
