# %%
import hmdb

# %%
# Delete the old dataframes to cleanup and prevent any overlap
if 'atlas' in locals() or 'atlas' in globals(): del atlas
if 'filtered_df' in locals() or 'filtered_df' in globals(): del filtered_df

# Read my database and pull into a dataframe
atlas_filename = "atlas_db.csv"
atlas = hmdb.read_atlas(atlas_filename)

# %%
# Filter the Atlas database to markers that has HMDB entry but are not in OSM
county = "Denton"
#Hemphill
#San Jacinto
#Throckmorton
#Titus
#Trinity
#Tyler
#Upshur
#Upton
#Uvalde
#Val Verde
#Van Zandt
#Victoria
#Walker
#Ward
#Washington
#Webb
#Wharton
#Wheeler
#Wichita
#Wilbarger
#Williamson
#Wilson
#Wise
#Wood
#Yoakum
#Young
#Zapata


filtered_df = atlas[(atlas['addr:county'] == county) & (atlas['ref:hmdb'].notna()) & (atlas['ref:US-TX:thc'].notna()) & (atlas['isHMDB'] == True) & (atlas['isOSM'] == False)]

## Regardless of County, showing missing OSM
##filtered_df = atlas[(atlas['ref:hmdb'].notna()) & (atlas['ref:US-TX:thc'].notna()) & (atlas['isHMDB'] == True) & (atlas['isOSM'] == False)]

if filtered_df.empty:
    print("The DataFrame is empty")
else:
    print(f"There are {filtered_df.shape[0]} rows in the filtered dataframe meeting the criteria")
# Out:
# There are 3 rows in the filtered dataframe meeting the criteria

# %%
# Create JOSM nodes from a filtered dataframe
### Do this the first time pushing to JOSM, otherwise you have to accept a lot of tags
#nodes = hmdb.create_nodes(filtered_df.head(1))
nodes = hmdb.create_nodes(filtered_df)
        
# Push the created nodes to JOSM
updated_nodes = hmdb.push2josm(nodes)
# Out:
# Failed to add node at (nan, nan). Status code: 400
# Failed to add node at (nan, nan). Status code: 400
# Completed pushing 15 nodes to JOSM

# %%
# Once the nodes are in OSM, update the dataframe to reflect "inOSM"=True
atlas = hmdb.update_isOSM(updated_nodes, atlas)
# Out:
# 2 fields were updated

# %%
### Go back up and run another county, OR
#     run the block below to save work.

# %%
# Write the dataframe back out to csv file. 
#  The file will prepend to date to prevent overwriting to "orginal" file. 
#  Make sure you update file names by copying file into archive then removing the date to make it the latest.
hmdb.write2csv(atlas, atlas_filename)
hmdb.write2csv(atlas, atlas_filename,True)
# Out:
# atlas_db.csv written to disk.
# ./file_backup/20241226_atlas_db.csv written to disk.

# %%
atlas.head(1)
# Out:
#    ref:US-TX:thc  ref:hmdb           name  \
# 0           2551    292905  Hood Cemetery
#
#                                           website memorial:website  \
# 0  https://atlas.thc.texas.gov/Details/5439002551              NaN
#
#   memorial:website.1  isTHC  isHMDB  isMissing  isPending  ...  hmdb:Latitude  \
# 0                NaN   True    True      False      False  ...      32.961239
#
#    hmdb:Longitude Recorded Texas Historic Landmark    thc:designation  \
# 0      -97.166408                            False  Historical Marker
#
#   Private Property                                       Marker Notes  \
# 0            False  Coventry Lane at King's Court, Southlake; in C...
#
#    wikimedia_commons                                        Marker Text  \
# 0                NaN  This cemetery was established on the farm of P...
#
#    inscription_size  DATA_NOTE
# 0             563.0        NaN
#
# [1 rows x 30 columns]

# %%
type(atlas['thc:Latitude'])
# Out:
# pandas.core.series.Series

# %%
column_names_list = atlas.columns.tolist()
print(column_names_list)

# %%
filtered_df
# Out:
#        ref:US-TX:thc  ref:hmdb                                        name  \
# 88                94    264185              Ahavath Sholom Hebrew Cemetery
# 331              349    263917                            Bedford Cemetery
# 1230            1355    201944  Southwestern Exposition and Livestock Show
# 1367            1506    264190                          Euday Louis Bowman
# 2015            2233    264203               Governor Charles A. Culberson
# 2532            2800    264153  John Peter Smith, Oakwood Cemetery Founder
# 2655            2936    264206                    Khleber Miller Van Zandt
# 2755            3053    264208                    Lawrence Clifton Elliott
# 3303            3659    264151                            Oakwood Cemetery
# 3962            4377    264211                          Royal Flying Corps
# 4972            5506    263918                             Tomlin Cemetery
# 5386            5985    240813                   General Edward H. Tarrant
# 10700          11847    269129                            Skinner Cemetery
# 11050          12206    263919                                Friday House
# 11314          12476    264186                                  Billy Muth
#
#        OsmNodeID                                         website  \
# 88           NaN  https://atlas.thc.texas.gov/Details/5439000094
# 331          NaN  https://atlas.thc.texas.gov/Details/5439000349
# 1230         NaN  https://atlas.thc.texas.gov/Details/5439001355
# 1367         NaN  https://atlas.thc.texas.gov/Details/5439001506
# 2015         NaN  https://atlas.thc.texas.gov/Details/5439002233
# 2532         NaN  https://atlas.thc.texas.gov/Details/5439002800
# 2655         NaN  https://atlas.thc.texas.gov/Details/5439002936
# 2755         NaN  https://atlas.thc.texas.gov/Details/5439003053
# 3303         NaN  https://atlas.thc.texas.gov/Details/5439003659
# 3962         NaN  https://atlas.thc.texas.gov/Details/5439004377
# 4972         NaN  https://atlas.thc.texas.gov/Details/5439005506
# 5386         NaN  https://atlas.thc.texas.gov/Details/5439005985
# 10700        NaN  https://atlas.thc.texas.gov/Details/5121011847
# 11050        NaN  https://atlas.thc.texas.gov/Details/5439012206
# 11314        NaN  https://atlas.thc.texas.gov/Details/5439012476
#
#                           memorial:website  isTHC  isHMDB  isMissing  \
# 88     https://www.hmdb.org/m.asp?m=264185   True    True      False
# 331    https://www.hmdb.org/m.asp?m=263917   True    True      False
# 1230   https://www.hmdb.org/m.asp?m=201944   True    True      False
# 1367   https://www.hmdb.org/m.asp?m=264190   True    True      False
# 2015   https://www.hmdb.org/m.asp?m=264203   True    True      False
# 2532   https://www.hmdb.org/m.asp?m=264153   True    True      False
# 2655   https://www.hmdb.org/m.asp?m=264206   True    True      False
# 2755   https://www.hmdb.org/m.asp?m=264208   True    True      False
# 3303   https://www.hmdb.org/m.asp?m=264151   True    True      False
# 3962   https://www.hmdb.org/m.asp?m=264211   True    True      False
# 4972   https://www.hmdb.org/m.asp?m=263918   True    True      False
# 5386   https://www.hmdb.org/m.asp?m=240813   True    True      False
# 10700                                  NaN   True    True      False
# 11050  https://www.hmdb.org/m.asp?m=263919   True    True      False
# 11314  https://www.hmdb.org/m.asp?m=264186   True    True      False
#
#        isPending  ...                   thc:designation Private Property  \
# 88         False  ...                 Historical Marker            False
# 331        False  ...                 Historical Marker            False
# 1230       False  ...                 Historical Marker            False
# 1367       False  ...                 Historical Marker            False
# 2015       False  ...                 Historical Marker            False
# 2532       False  ...                 Historical Marker            False
# 2655       False  ...                 Historical Marker            False
# 2755       False  ...                 Historical Marker            False
# 3303       False  ...  Recorded Texas Historic Landmark            False
# 3962       False  ...                 Historical Marker            False
# 4972       False  ...                 Historical Marker            False
# 5386       False  ...                 Historical Marker            False
# 10700      False  ...                 Historical Marker            False
# 11050      False  ...  Recorded Texas Historic Landmark             True
# 11314      False  ...                 Historical Marker            False
#
#                                             Marker Notes  \
# 88     Ahavath Sholom Hebrew Cemetery entrance, west ...
# 331                                                  NaN
# 1230   Stockyards Blvd., S side 100 feet E. of Rodeo ...
# 1367   Oakwood Cemetery, section 21, 701 Grand Ave. F...
# 2015   Oakwood Cemetery, Sect. 31, 700 Grand Ave., Fo...
# 2532   700 Grand Ave., Fort Worth, Oakwood Cemetery e...
# 2655        700 Grand Ave., Oakwood Cemetery, Section 29
# 2755         Greenwood Memorial Park, Sec. 40 (Devotion)
# 3303   Grand at Gould Avenue, Oakwood Cemetery, at ga...
# 3962                Greenwood Memorial Park, Section 5-H
# 4972                 Tomlin Lane, Arlington; at dead end
# 5386                                                 NaN
# 10700  Skinner Cemetery, east side of Debbie Lane, ap...
# 11050  This is a private residence, please be respect...
# 11314      Greenwood Memorial Park, Sec. 37 (Meditation)
#
#                                        wikimedia_commons  \
# 88                                                   NaN
# 331                                                  NaN
# 1230                                                 NaN
# 1367    File:Historical Marker of Euday Louis Bowman.jpg
# 2015   File:Historical Marker of Governor Charles A. ...
# 2532      File:Historical Marker of John Peter Smith.jpg
# 2655   File:Historical Marker of Khleber Miller Van Z...
# 2755   File:Historical Marker of Lawrence Clifton Ell...
# 3303      File:Historical Marker of Oakwood Cemetery.jpg
# 3962    File:Historical Marker in Royal Flying Corps.jpg
# 4972                                                 NaN
# 5386                                                 NaN
# 10700                                                NaN
# 11050                                                NaN
# 11314           File:Historical Marker of Billy Muth.jpg
#
#                             subject:wikimedia_commons  \
# 88                                                NaN
# 331                         File:Bedford_Cemetery.jpg
# 1230                                              NaN
# 1367                                  File:Bowman.jpg
# 2015                 File:Charles Allen Culberson.jpg
# 2532                        File:John Peter Smith.jpg
# 2655                File:Khleber Miller Van Zandt.jpg
# 2755                                              NaN
# 3303                File:OakwoodCemetery (1 of 1).jpg
# 3962                                              NaN
# 4972                         File:Tomlin_Cemetery.jpg
# 5386                                              NaN
# 10700  File:Historical Marker of Skinner Cemetery.jpg
# 11050                           File:Friday_House.jpg
# 11314          File:William McKinley “Billy” Muth.jpg
#
#                              subject:wikipedia  subject:wikidata  \
# 88                                         NaN               NaN
# 331                                        NaN               NaN
# 1230                                       NaN               NaN
# 1367                        en:Euday L. Bowman          Q3059496
# 2015                   en:Charles A. Culberson           Q477807
# 2532                                       NaN               NaN
# 2655               en:Khleber Miller Van Zandt          Q6401821
# 2755                                       NaN               NaN
# 3303   en:Oakwood Cemetery (Fort Worth, Texas)         Q49001445
# 3962                     en:Royal_Flying_Corps           Q943118
# 4972                                       NaN               NaN
# 5386                                       NaN               NaN
# 10700                                      NaN        Q117498828
# 11050                                      NaN               NaN
# 11314                                      NaN        Q131661787
#
#                                              Marker Text  inscription_size  \
# 88     Wishing to have their own cemetery, congregati...            1197.0
# 331    Pioneers probably began using this graveyard d...             597.0
# 1230   Fort Worth became an important trading and sup...            1295.0
# 1367   (Nov. 9, 1886 - May 26, 1949) Fort Worth nativ...             476.0
# 2015   (June 10, 1855 - March 19, 1925) A native of A...             579.0
# 2532   Pioneer area settler John Peter Smith (1831-19...            1220.0
# 2655   Khleber Miller Van Zandt (1836-1930) Tennessee...             642.0
# 2755   (November 16, 1901 - May 15, 1970) Aviation pi...            1291.0
# 3303   Founded 1879 by John Peter Smith, one of Fort ...             571.0
# 3962   In 1917, during World War I, the U.S., British...            1178.0
# 4972   This cemetery was first used in the 1870s by t...             552.0
# 5386                                                 NaN               0.0
# 10700  In the early days of Pilot Point, Lucinda (Gla...            1254.0
# 11050  In 1923, Marion and Willie Maybelle Friday pur...             798.0
# 11314  William McKinley (Billy) Muth (1902-1949) made...             599.0
#
#       DATA_NOTE
# 88          NaN
# 331         NaN
# 1230        NaN
# 1367        NaN
# 2015        NaN
# 2532        NaN
# 2655        NaN
# 2755        NaN
# 3303        NaN
# 3962        NaN
# 4972        NaN
# 5386        NaN
# 10700       NaN
# 11050       NaN
# 11314       NaN
#
# [15 rows x 34 columns]
